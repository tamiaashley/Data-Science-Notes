# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tamia-Ashley Tuitt**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I love workign and manipulatng data to solve complex problems*

# %% [markdown]
# ### The following code finds the average of two numbers:

# %%
average = (50 + 70)/2
print(average)
# Out:
# 60.0

# %% [markdown]
# |MY FAVOURITE DATA SCIENCE TOOLS|
# |-------------------------------|
# | Rstudio|
# |Jupyter Notebooks|
# |Visual Studio |
#
#
# I like these tools because:
# 1. They are fun and easy to work with
# 2. I enjoy seeing my visualizations in real time
# 3. The interface feels light and managable
#
# My favourite languages are:
# + R
# + Python
# + C++
